# %%
# record coordination upon click
import matplotlib.pyplot as plt


# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(np.random.rand(10))
text=ax.text(0,0, "", va="bottom", ha="left")

clicks = []

def onclick(event):
    global clicks
    clicks.append((event.button, event.x, event.y, event.xdata, event.ydata))
    tx = 'button=%d, x=%d, y=%d, xdata=%f, ydata=%f' % (event.button, event.x, event.y, event.xdata, event.ydata)
    text.set_text(tx)

cid = fig.canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# cont'ed record coordination upon click
print(clicks)
# Out:
# [(1, 637, 193, 6.4319302405080485, 0.19342602556759386), (1, 577, 259, 5.633543143733855, 0.3150838108504349), (1, 527, 351, 4.974873788895145, 0.4824776169720308), (1, 500, 270, 4.615599595346758, 0.3342929389746235), (1, 308, 324, 2.0607608856693393, 0.4330827138380871)]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\Ruocun\Desktop\ECSHackWeek\Voltammetry\voltammetry.py\Data\Data from voltcycle\10mM_F2CA_1M_KOH_pH_14_100mV_txt.txt',sep='\t',skiprows=64,skipfooter=4,engine='python',header=None,names=['Pt','t','Vf','Im','Vu','Sig','Ach','IErange','Over'])

#df.head()
#df.iloc[10]
df.set_index('Pt',inplace = True)
#df['Vf']

plt.figure(figsize=(6, 4))
plt.scatter(df['Vf'],df['Im'])
# Out:
# <img src="data:image/png;base64,..." width="599.2593015924596">

# %%
import numpy as np

# Seed the random number generator for reproducibility
np.random.seed(0)

x_data = np.linspace(-5, 5, num=50)
y_data = 2.9 * np.sin(1.5 * x_data) + np.random.normal(size=50)

# And plot it
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 4))
plt.scatter(x_data, y_data)
# Out:
# <img src="data:image/png;base64,..." width="666.666713761698">

# %%
from scipy import optimize

def test_func(x, a, b):
    return a * np.sin(b * x)

params, params_covariance = optimize.curve_fit(test_func, x_data, y_data,
                                               p0=[2, 2])

print(params)
# Out:
# [3.05931973 1.45754553]

# %%
plt.figure(figsize=(6, 4))
plt.scatter(x_data, y_data, label='Data')
plt.plot(x_data, test_func(x_data, params[0], params[1]),
         label='Fitted function')

plt.legend(loc='best')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="666.666713761698">

# %%
df = pd.DataFrame([1,2,3],[3,4,5])
df1 = df.to_numpy()
print(df1[])
# Out:
# [[1]
#  [2]
#  [3]]
